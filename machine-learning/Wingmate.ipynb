# %% [markdown]
# <a href="https://colab.research.google.com/github/aahxe/AudioClassifier/blob/main/machine-learning/Wingmate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mounting to google drive as mp3, github repo and custom model are saved there

from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/gdrive', force_remount=True)
#drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/SIS/WORKING
# Out:
# /content/gdrive/My Drive/SIS/WORKING

# %%
pwd
# Out:
# '/content/gdrive/My Drive/SIS/WORKING'

# %%
#THIS VERSION OF TENSORFLOW IS CRUCIAL AS WELL AS KERAS 2

pip install tensorflow==2.15.1

# %%
# REQUIRED TO PROCESS SOME AUDIO FILES FOR ANALYSIS

pip install resampy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 6.9 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.1

# %%
import keras
print(keras.__version__)
# Out:
# 2.15.0

# %%
# cloning birdnet model
# !git clone https://github.com/kahst/BirdNET-Analyzer.git
# Out:
# Cloning into 'BirdNET-Analyzer'...
# remote: Enumerating objects: 2969, done.
# remote: Counting objects: 100% (586/586), done.
# remote: Compressing objects: 100% (275/275), done.
# remote: Total 2969 (delta 352), reused 514 (delta 305), pack-reused 2383 (from 1)
# Receiving objects: 100% (2969/2969), 1.15 GiB | 12.73 MiB/s, done.
# Resolving deltas: 100% (1774/1774), done.
# Updating files: 100% (109/109), done.

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/SIS/WORKING/BirdNET-Analyzer'

# %%
# %cd "/content/gdrive/MyDrive/SIS/WORKING/BirdNET-Analyzer"
# Out:
# /content/gdrive/MyDrive/SIS/WORKING/BirdNET-Analyzer

# %%
# --i "path to input mp3"
# --o "path to output folder (currently a table in the form of a text file)"
# --classifier "path to the tflite model /.../wingmatecustom/plsworkmodel.tflite"

# !python analyze.py --i "input" --o "output" --classifier  "model"
# Out:
# Species list contains 18 species
# Analyzing /content/gdrive/MyDrive/SIS/dunnock;archivebirdsnz;1.mp3
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: Attempting to use a delegate that only supports static-sized tensors with a graph that has dynamic-sized tensors (tensor#187 is a dynamic-sized tensor).
# Finished /content/gdrive/MyDrive/SIS/dunnock;archivebirdsnz;1.mp3 in 9.40 seconds
